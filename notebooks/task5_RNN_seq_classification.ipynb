# %% [markdown]
# # Task 5
#
# - Implement seq2seq model
#     - build simple translation model based on encoder-decoder architecture.
#     - Choice of encoder and decoder layers is up to you. Of course, it should contain at least one embeddings layer and one layer of RNN.
#     - Train model and run inference.
#
# - Augment created seq2seq model with attention mechanism.
#     - Choice of score metrics (dot product or weights matrix) is up to you.
#     - Train model and run inference.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim # to update model parameters
from torch.utils.data import Dataset, DataLoader

# %%
base_path = os.getcwd()
file_path = os.path.abspath(os.path.join(base_path, "..", "data", "without_chap_and_title", "eng_Anne_full_abbr.txt"))
text = open(file_path, encoding="utf-8").read()

# %% [markdown]
# ## Encoder

# %% [markdown]
# ## Decoder
