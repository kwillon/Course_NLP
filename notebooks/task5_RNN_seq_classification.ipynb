# %% [markdown]
# **For RNN, you can choose any task: name tagging (predicting tag for each word), sentence classification or next token generation - up to your preference.**
#
# I want to classify the text in which language

# %% [markdown]
# # Task 5
